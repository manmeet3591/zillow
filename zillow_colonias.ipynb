# %%
import pandas as pd

# %%
df = pd.read_csv('County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')

# %%
df[df['RegionName']=='Hidalgo County']
# Out:
#       RegionID  SizeRank      RegionName RegionType StateName State  \
# 66        1776        66  Hidalgo County     county        TX    TX
# 2856      1775      2950  Hidalgo County     county        NM    NM
#
#                              Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 66    McAllen-Edinburg-Mission, TX             48                215
# 2856                           NaN             35                 23
#
#       2000-01-31  ...     2024-06-30     2024-07-31     2024-08-31  \
# 66           NaN  ...  190124.112958  189810.742326  189808.661969
# 2856         NaN  ...  102346.718777  102237.603724  102195.545575
#
#          2024-09-30     2024-10-31     2024-11-30     2024-12-31  \
# 66    189907.729889  190335.722196  190572.801433  190714.144510
# 2856  102525.005816  102303.551024  101492.683785  100829.383899
#
#          2025-01-31     2025-02-28     2025-03-31
# 66    190666.891534  190412.677784  189741.876060
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
# Filter for Hidalgo County in Texas
df_filtered = df[(df['RegionName'] == 'Hidalgo County') & (df['StateName'] == 'TX')]

# Extract the time series data
time_series = df_filtered.iloc[0, 10:]
time_series.index = pd.to_datetime(time_series.index)
time_series = pd.to_numeric(time_series, errors='coerce')

# Plot
plt.figure(figsize=(12, 6))
plt.plot(time_series.index, time_series.values, label='ZHVI - Hidalgo County, TX')
plt.title('Zillow Home Value Index (ZHVI)\nMcAllen-Edinburg-Mission Metro')
plt.xlabel('Date')
plt.ylabel('ZHVI ($)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
